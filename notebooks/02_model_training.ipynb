# %% [markdown]
# # Model training and evaluation
# The script compares a mean baseline, Ridge, ExtraTrees, standard HistGradientBoosting, and a lightly tuned HistGradientBoosting regressor using a chronological holdout.

# %%
import sys
from pathlib import Path
project_root = Path.cwd()
while not (project_root / "src").exists() and project_root != project_root.parent:
    project_root = project_root.parent
sys.path.insert(0, str(project_root))
from src.train import main
main(project_root, project_root / "results")
