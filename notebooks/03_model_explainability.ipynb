# %% [markdown]
# # Model explainability
# This notebook creates a global SHAP importance table, summary plot, and local waterfall plot for the saved best model.

# %%
import sys
from pathlib import Path
project_root = Path.cwd()
while not (project_root / "src").exists() and project_root != project_root.parent:
    project_root = project_root.parent
sys.path.insert(0, str(project_root))
from src.explain import main
main(project_root, project_root / "results/best_model.joblib", project_root / "results")
